# %%
import numpy as np
import pickle

from scipy.sparse import csr_matrix
from scripts.caracteristica import caracteristica
from datasketch import MinHash, MinHashLSH

from tqdm import tqdm

# %%
n_perm = 128

def minhash_vector(sparse_vector:csr_matrix, num_perm:int=n_perm):
    minhash = MinHash(num_perm=num_perm)
    for index in sparse_vector.indices:
        minhash.update(str(index).encode('utf8'))
    return minhash

# %%
k = 2

# sample_size = 20_000
# matrix, tweets = caracteristica(k, sample_size)

matrix, tweets = caracteristica(k)

# %%
threshold = 0.2
lsh = MinHashLSH(threshold=threshold, num_perm=n_perm)
hashes = []

for i in tqdm(range(matrix.shape[0])):
    hashes.append((i, minhash_vector(matrix[i])))

with lsh.insertion_session() as session:
    for i, minhash in tqdm(hashes):
        session.insert(i, minhash)
# Out:
# 100%|██████████| 1371764/1371764 [17:31<00:00, 1304.02it/s]
# 100%|██████████| 1371764/1371764 [01:16<00:00, 18027.95it/s]

# %%
pickle.dump(lsh, open(f'../Data/lsh/k{k}_th{threshold}.pkl', 'wb'))

# %%
m = minhash_vector(matrix[1500])
print(lsh.query(m))
print(len(lsh.query(m)))
# Out:
# [565250, 1122311, 36873, 917520, 1099796, 256023, 612375, 653337, 1357863, 518189, 991278, 1026095, 782384, 217134, 1361970, 202800, 1108017, 714797, 194614, 260151, 686134, 755769, 280636, 200774, 528455, 88141, 839757, 1359949, 833621, 630871, 1065048, 1189977, 839767, 634969, 827484, 1304673, 931938, 1060963, 1153124, 129128, 579689, 1263721, 1181800, 1116268, 798825, 10346, 1265776, 964721, 573555, 1200246, 618618, 751739, 983164, 206975, 1165440, 688258, 10372, 49285, 440454, 1259655, 1011852, 921742, 280720, 1095825, 311442, 620690, 735386, 92315, 641181, 176289, 491681, 280741, 190630, 1093798, 1106088, 1200299, 821423, 1052850, 329912, 364728, 1192126, 1134783, 977088, 6337, 1343685, 620741, 573639, 817352, 735433, 221387, 248012, 1360076, 1319119, 1192144, 794834, 544979, 897235, 41175, 92381, 280797, 1046751, 266464, 192737, 1046752, 809187, 233701, 336102, 1059053, 176368, 28913, 1235186, 264432, 1007860, 82163, 401656, 1265915, 350461, 1235198, 1353983, 1310977, 358660, 73996, 821517, 928014, 409872, 1206545, 198929, 735506, 176403, 606485, 606489, 260381, 1290525, 653600, 895266, 1120547, 1175850, 536880, 266545, 266546, 368945, 878897, 1163568, 61751, 948539, 1159483, 571711, 1274179, 178501, 1067335, 362826, 676170, 1155408, 1198418, 340308, 442714, 1282394, 319835, 1241439, 184674, 1060858, 936290, 502119, 2408, 1007977, 985451, 1134956, 1112429, 348527, 49519, 659823, 319858, 254324, 500086, 1057142, 985464, 6518, 393600, 643458, 1051013, 842118, 1311111, 346505, 620938, 65931, 1155469, 41357, 889229, 569742, 1266069, 278934, 8602, 29084, 688540, 10665, 328105, 686513, 358836, 88500, 541109, 651703, 752073, 49610, 1364425, 889291, 1235405, 106958, 113103, 1362392, 1165787, 188893, 621024, 821730, 1001954, 166372, 1047014, 1049066, 223722, 493, 188909, 635374, 524788, 856565, 1014261, 285176, 1331705, 377348, 303621, 266758, 950792, 317963, 10764, 426509, 217614, 686605, 360975, 1196565, 1348119, 832027, 1258019, 784932, 580131, 971307, 739884, 6704, 821808, 832050, 383548, 930374, 479821, 789069, 694861, 438864, 156239, 156242, 559695, 1022544, 408149, 1319504, 1047126, 1071706, 567899, 100958, 1344095, 1278560, 916070, 397927, 832104, 449127, 1309290, 586347, 701036, 408170, 1002099, 92790, 125560, 47741, 785023, 543361, 699010, 1247874, 383619, 326277, 43654, 328326, 1319557, 1055369, 1186443, 819853, 361103, 322191, 832144, 782994, 844435, 256657, 1307283, 889492, 948886, 1012369, 266905, 1313434, 533155, 723622, 1256108, 682673, 1155762, 158391, 918200, 78521, 1317561, 1297084, 1030847, 942793, 266954, 1176266, 1325771, 346829, 387790, 531151, 1241810, 457434, 168667, 1282779, 70365, 637663, 1102561, 1329890, 1297123, 6887, 1274600, 1317612, 821996, 965359, 760560, 920304, 467697, 25338, 373500, 1153796, 531205, 310026, 539403, 1121037, 1155855, 811795, 152343, 148248, 1057563, 887580, 351006, 64288, 1137445, 1284902, 129835, 1233708, 600888, 1354554, 723772, 459581, 1360701, 252735, 29504, 490303, 969538, 437052, 580420, 627525, 138058, 49995, 678732, 197450, 99151, 783184, 1317718, 1160024, 1061723, 222048, 992098, 113507, 185188, 744298, 1192816, 963441, 146290, 510834, 879477, 1260406, 263030, 1090424, 533374, 590719, 72579, 361348, 254856, 197514, 138125, 998285, 177039, 844688, 84882, 1149845, 1104789, 668568, 56218, 664477, 740255, 11170, 1090467, 1086372, 881574, 1139624, 498601, 836524, 760750, 865202, 1020853, 189367, 13241, 78783, 590787, 177094, 1108935, 492492, 1356750, 861135, 469973, 1113045, 82902, 240600, 539608, 842717, 406495, 226278, 1135592, 1108973, 787441, 1133553, 842742, 895994, 908283, 406525, 183294, 226303, 1244163, 603139, 676869, 955395, 254983, 1246217, 961547, 1338381, 525326, 924687, 709649, 1360914, 347155, 58389, 240662, 490519, 922645, 1008665, 66590, 1176608, 1180704, 1029155, 988196, 676902, 1104938, 777259, 982060, 963629, 1166384, 603187, 441397, 89145, 240699, 1033280, 986177, 1045570, 1199170, 341061, 480327, 1305673, 1360969, 1223755, 928842, 253005, 627788, 51924 ...
# 909
